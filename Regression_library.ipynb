# %% [markdown]
# <a href="https://colab.research.google.com/github/dawipayandas/my-colab-projects/blob/main/Regression_library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/sample_data/placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel("CGPA")
plt.ylabel("Package")
# Out:
# Text(0, 0.5, 'Package')

# %%
X=df.iloc[:,0:1]

# %%
Y=df.iloc[:, -1]

# %%
Y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test=train_test_split(X,Y,test_size=0.2, random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
X_test.head()
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57

# %%
lr.predict(X)
# Out:
# array([2.94817717, 1.96060218, 3.46707251, 3.24389172, 2.97607477,
#        3.50612915, 2.85890486, 2.8700639 , 2.5018156 , 3.74046898,
#        2.07219258, 2.79195062, 4.09197872, 2.97049525, 3.41685683,
#        3.14903989, 2.92027958, 2.10566969, 2.97607477, 3.27736884,
#        3.16577844, 2.9258591 , 2.52971319, 2.55761079, 2.74731446,
#        3.16577844, 3.74046898, 2.12798777, 2.4181228 , 3.09324469,
#        3.2104146 , 3.62329906, 2.98723381, 2.64688311, 3.19925556,
#        2.93701814, 2.4460204 , 2.39580472, 3.91343409, 3.24947124,
#        4.33747759, 2.94817717, 2.42370232, 3.37780019, 1.94386362,
#        3.49497011, 2.49065656, 2.3623276 , 3.91901361, 4.05292208,
#        4.44906798, 4.27052335, 3.7739461 , 2.71383735, 2.93143862,
#        3.67909426, 2.3623276 , 2.7863711 , 2.96491573, 3.322005  ,
#        2.23399865, 2.16146489, 2.64130359, 4.21472815, 3.2104146 ,
#        3.34432308, 1.95502266, 2.73615542, 3.322005  , 3.17693748,
# ...

# %%
lr.predict(X_train.iloc[[1]])
# Out:
# array([4.0863992])

# %%
X_train.head()
# Out:
#      cgpa
# 137  7.14
# 163  8.93
# 111  5.42
# 123  5.10
# 109  7.77

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train, lr.predict(X_train), color='green')
plt.xlabel("CGPA")
plt.ylabel("Package")
# Out:
# Text(0, 0.5, 'Package')

# %%
lr.coef_
# Out:
# array([0.55795197])

# %%
lr.intercept_
# Out:
# np.float64(-0.8961119222429144)
