# %% [markdown]
# <a href="https://colab.research.google.com/github/dawipayandas/my-colab-projects/blob/main/Multi_batchGD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_diabetes
import numpy as np

# %%
x,y=load_diabetes(return_X_y=True)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.coef_, lr.intercept_
# Out:
# (array([ -10.0098663 , -239.81564367,  519.84592005,  324.3846455 ,
#         -792.17563855,  476.73902101,  101.04326794,  177.06323767,
#          751.27369956,   67.62669218]),
#  np.float64(152.13348416289597))

# %%
class MultiGD:
  def __init__(self, lr=0.01, epoch=100):
    self.coef_=None
    self.intercept_=None
    self.lr=lr
    self.epoch=epoch

  def fit(self,x,y):
    self.coef_=np.ones(x.shape[1])
    self.intercept_=0
    y=y.ravel()
    for i in range(self.epoch):
      y_pred=self.intercept_+ x.dot(self.coef_)
      intercept_der=-2*np.mean(y-y_pred)
      self.intercept_=self.intercept_-self.lr*intercept_der

      coef_der=-2*np.dot((y-y_pred),x)/x.shape[0]
      self.coef_=self.coef_-self.lr*coef_der
    print(self.intercept_, self.coef_)

# %%
bgd=MultiGD(0.99,100000)

# %%
bgd.fit(x,y)
# Out:
# 152.133484162896 [  -9.93413525 -239.73067597  520.03736082  324.30984939 -775.70009432
#   463.66594729   93.67461621  174.96028944  745.13481939   67.6872905 ]
